# %%
from faker import Faker
import pandas as pd

# %%
df = pd.read_csv('dataset/data_cleaned.csv')
fake = Faker('id_ID')

# %%
new_df = df[["job_title", "job_description"]]
new_df = new_df.rename(columns={"job_description": "description", "job_title": "jobTitle"})
new_df
# Out:
#                                                 jobTitle  \
# 0                            Procurement Department Head
# 1                                            SALES ADMIN
# 2           City Operation Lead Shopee Express (Cirebon)
# 3                                   Japanese Interpreter
# 4                                      Admin Online Shop
# ...                                                  ...
# 24819                                         Accounting
# 24820                                   Staff Accounting
# 24821                                 Frontend Developer
# 24822                                    Account Manager
# 24823  Credit Marketing Officer (CMO) - Tangerang & C...
#
#                                              description
# 0      Job Role  1. Responsible for material availabi...
# 1      Internal Sales   AdminJob Description  We are ...
# 2      Job Description Responsible for HSE implementa...
# 3      Overview  Our clients is manufacture for autom...
# 4      Deskripsi Pekerjaan Dapat menggunakan aplikasi...
# ...                                                  ...
# 24819  Usia maksimal 35 tahunPendidikan S1 Accounting...
# 24820  Candidate must possess at least Bachelor s Deg...
# 24821  job description  1.Participate in the daily de...
# 24822  Tugas   Tanggung Jawab Melakukan program pemas...
# 24823  CMO Motor BaruMelakukan penjualan produk pembi...
#
# [24824 rows x 2 columns]

# %%
company_names = []
for _ in range(24824):
    company_name = fake.company()
    company_names.append(company_name)

faker_df = pd.DataFrame({'companyName': company_names})
faker_df
# Out:
#                                  companyName
# 0           PT Safitri Safitri (Persero) Tbk
# 1           UD Dabukke Pranowo (Persero) Tbk
# 2                               PD Sihombing
# 3                      CV Tampubolon Gunawan
# 4                                  PT Melani
# ...                                      ...
# 24819                   PT Anggriawan Melani
# 24820          Perum Sihombing (Persero) Tbk
# 24821  CV Nashiruddin Suryatmi (Persero) Tbk
# 24822             CV Mardhiyah Manullang Tbk
# 24823                 PT Padmasari Anggraini
#
# [24824 rows x 1 columns]

# %%
addresses = []
for _ in range(24824):
    address = fake.address()
    addresses.append(address.split("\n")[0])

faker_df['address'] = addresses
faker_df
# Out:
#                                  companyName                       address
# 0           PT Safitri Safitri (Persero) Tbk     Jalan Suryakencana No. 12
# 1           UD Dabukke Pranowo (Persero) Tbk  Jalan Rungkut Industri No. 2
# 2                               PD Sihombing       Gg. Moch. Ramdan No. 94
# 3                      CV Tampubolon Gunawan          Gg. Joyoboyo No. 004
# 4                                  PT Melani               Gang BKR No. 83
# ...                                      ...                           ...
# 24819                   PT Anggriawan Melani         Jl. Ciumbuleuit No. 1
# 24820          Perum Sihombing (Persero) Tbk       Gg. Asia Afrika No. 476
# 24821  CV Nashiruddin Suryatmi (Persero) Tbk       Gang Cihampelas No. 894
# 24822             CV Mardhiyah Manullang Tbk             Jl. Cempaka No. 3
# 24823                 PT Padmasari Anggraini             Jl. Kutai No. 015
#
# [24824 rows x 2 columns]

# %%
phoneNumbers = []
for _ in range(24824):
    phoneNumber = fake.phone_number()
    phoneNumbers.append(phoneNumber)

faker_df['phoneNumber'] = phoneNumbers
faker_df
# Out:
#                                  companyName                       address  \
# 0           PT Safitri Safitri (Persero) Tbk     Jalan Suryakencana No. 12
# 1           UD Dabukke Pranowo (Persero) Tbk  Jalan Rungkut Industri No. 2
# 2                               PD Sihombing       Gg. Moch. Ramdan No. 94
# 3                      CV Tampubolon Gunawan          Gg. Joyoboyo No. 004
# 4                                  PT Melani               Gang BKR No. 83
# ...                                      ...                           ...
# 24819                   PT Anggriawan Melani         Jl. Ciumbuleuit No. 1
# 24820          Perum Sihombing (Persero) Tbk       Gg. Asia Afrika No. 476
# 24821  CV Nashiruddin Suryatmi (Persero) Tbk       Gang Cihampelas No. 894
# 24822             CV Mardhiyah Manullang Tbk             Jl. Cempaka No. 3
# 24823                 PT Padmasari Anggraini             Jl. Kutai No. 015
#
#                phoneNumber
# 0               0808211883
# 1        +62 (69) 978-8049
# 2        +62-0175-406-9923
# 3        +62-0126-859-2299
# 4        +62 (22) 958-5994
# ...                    ...
# 24819  +62 (0753) 440-1069
# 24820         088 916 5849
# 24821    +62 (15) 140 1171
# 24822    +62 (34) 362-5283
# 24823  +62 (0293) 341-4033
#
# [24824 rows x 3 columns]

# %%
def generate_email(company_name):
    parsed_name = company_name.replace(" ", "").lower()
    email = parsed_name + "@email.com"
    return email

faker_df['email'] = faker_df['companyName'].apply(generate_email)
faker_df
# Out:
#                                  companyName                       address  \
# 0           PT Safitri Safitri (Persero) Tbk     Jalan Suryakencana No. 12
# 1           UD Dabukke Pranowo (Persero) Tbk  Jalan Rungkut Industri No. 2
# 2                               PD Sihombing       Gg. Moch. Ramdan No. 94
# 3                      CV Tampubolon Gunawan          Gg. Joyoboyo No. 004
# 4                                  PT Melani               Gang BKR No. 83
# ...                                      ...                           ...
# 24819                   PT Anggriawan Melani         Jl. Ciumbuleuit No. 1
# 24820          Perum Sihombing (Persero) Tbk       Gg. Asia Afrika No. 476
# 24821  CV Nashiruddin Suryatmi (Persero) Tbk       Gang Cihampelas No. 894
# 24822             CV Mardhiyah Manullang Tbk             Jl. Cempaka No. 3
# 24823                 PT Padmasari Anggraini             Jl. Kutai No. 015
#
#                phoneNumber                                        email
# 0               0808211883       ptsafitrisafitri(persero)tbk@email.com
# 1        +62 (69) 978-8049       uddabukkepranowo(persero)tbk@email.com
# 2        +62-0175-406-9923                        pdsihombing@email.com
# 3        +62-0126-859-2299                cvtampubolongunawan@email.com
# 4        +62 (22) 958-5994                           ptmelani@email.com
# ...                    ...                                          ...
# 24819  +62 (0753) 440-1069                 ptanggriawanmelani@email.com
# 24820         088 916 5849         perumsihombing(persero)tbk@email.com
# 24821    +62 (15) 140 1171  cvnashiruddinsuryatmi(persero)tbk@email.com
# 24822    +62 (34) 362-5283            cvmardhiyahmanullangtbk@email.com
# 24823  +62 (0293) 341-4033               ptpadmasarianggraini@email.com
#
# [24824 rows x 4 columns]

# %%
def generate_website(company_name):
    parsed_name = company_name.replace(" ", "-").lower()
    website = "www." + parsed_name + ".com"
    return website

faker_df['website'] = faker_df['companyName'].apply(generate_website)
faker_df
# Out:
#                                  companyName                       address  \
# 0           PT Safitri Safitri (Persero) Tbk     Jalan Suryakencana No. 12
# 1           UD Dabukke Pranowo (Persero) Tbk  Jalan Rungkut Industri No. 2
# 2                               PD Sihombing       Gg. Moch. Ramdan No. 94
# 3                      CV Tampubolon Gunawan          Gg. Joyoboyo No. 004
# 4                                  PT Melani               Gang BKR No. 83
# ...                                      ...                           ...
# 24819                   PT Anggriawan Melani         Jl. Ciumbuleuit No. 1
# 24820          Perum Sihombing (Persero) Tbk       Gg. Asia Afrika No. 476
# 24821  CV Nashiruddin Suryatmi (Persero) Tbk       Gang Cihampelas No. 894
# 24822             CV Mardhiyah Manullang Tbk             Jl. Cempaka No. 3
# 24823                 PT Padmasari Anggraini             Jl. Kutai No. 015
#
#                phoneNumber                                        email  \
# 0               0808211883       ptsafitrisafitri(persero)tbk@email.com
# 1        +62 (69) 978-8049       uddabukkepranowo(persero)tbk@email.com
# 2        +62-0175-406-9923                        pdsihombing@email.com
# 3        +62-0126-859-2299                cvtampubolongunawan@email.com
# 4        +62 (22) 958-5994                           ptmelani@email.com
# ...                    ...                                          ...
# 24819  +62 (0753) 440-1069                 ptanggriawanmelani@email.com
# 24820         088 916 5849         perumsihombing(persero)tbk@email.com
# 24821    +62 (15) 140 1171  cvnashiruddinsuryatmi(persero)tbk@email.com
# 24822    +62 (34) 362-5283            cvmardhiyahmanullangtbk@email.com
# 24823  +62 (0293) 341-4033               ptpadmasarianggraini@email.com
#
#                                              website
# 0           www.pt-safitri-safitri-(persero)-tbk.com
# 1           www.ud-dabukke-pranowo-(persero)-tbk.com
# 2                               www.pd-sihombing.com
# 3                      www.cv-tampubolon-gunawan.com
# 4                                  www.pt-melani.com
# ...                                              ...
# 24819                   www.pt-anggriawan-melani.com
# 24820          www.perum-sihombing-(persero)-tbk.com
# 24821  www.cv-nashiruddin-suryatmi-(persero)-tbk.com
# 24822             www.cv-mardhiyah-manullang-tbk.com
# 24823                 www.pt-padmasari-anggraini.com
#
# [24824 rows x 5 columns]

# %%
def generate_linkedin(company_name):
    parsed_name = company_name.replace(" ", "-").lower()
    linkedin = "www.linkedin.com/in/" + parsed_name + "/"
    return linkedin

faker_df['linkedin'] = faker_df['companyName'].apply(generate_linkedin)
faker_df
# Out:
#                                  companyName                       address  \
# 0           PT Safitri Safitri (Persero) Tbk     Jalan Suryakencana No. 12
# 1           UD Dabukke Pranowo (Persero) Tbk  Jalan Rungkut Industri No. 2
# 2                               PD Sihombing       Gg. Moch. Ramdan No. 94
# 3                      CV Tampubolon Gunawan          Gg. Joyoboyo No. 004
# 4                                  PT Melani               Gang BKR No. 83
# ...                                      ...                           ...
# 24819                   PT Anggriawan Melani         Jl. Ciumbuleuit No. 1
# 24820          Perum Sihombing (Persero) Tbk       Gg. Asia Afrika No. 476
# 24821  CV Nashiruddin Suryatmi (Persero) Tbk       Gang Cihampelas No. 894
# 24822             CV Mardhiyah Manullang Tbk             Jl. Cempaka No. 3
# 24823                 PT Padmasari Anggraini             Jl. Kutai No. 015
#
#                phoneNumber                                        email  \
# 0               0808211883       ptsafitrisafitri(persero)tbk@email.com
# 1        +62 (69) 978-8049       uddabukkepranowo(persero)tbk@email.com
# 2        +62-0175-406-9923                        pdsihombing@email.com
# 3        +62-0126-859-2299                cvtampubolongunawan@email.com
# 4        +62 (22) 958-5994                           ptmelani@email.com
# ...                    ...                                          ...
# 24819  +62 (0753) 440-1069                 ptanggriawanmelani@email.com
# 24820         088 916 5849         perumsihombing(persero)tbk@email.com
# 24821    +62 (15) 140 1171  cvnashiruddinsuryatmi(persero)tbk@email.com
# 24822    +62 (34) 362-5283            cvmardhiyahmanullangtbk@email.com
# 24823  +62 (0293) 341-4033               ptpadmasarianggraini@email.com
#
#                                              website  \
# 0           www.pt-safitri-safitri-(persero)-tbk.com
# 1           www.ud-dabukke-pranowo-(persero)-tbk.com
# 2                               www.pd-sihombing.com
# 3                      www.cv-tampubolon-gunawan.com
# 4                                  www.pt-melani.com
# ...                                              ...
# 24819                   www.pt-anggriawan-melani.com
# 24820          www.perum-sihombing-(persero)-tbk.com
# 24821  www.cv-nashiruddin-suryatmi-(persero)-tbk.com
# 24822             www.cv-mardhiyah-manullang-tbk.com
# 24823                 www.pt-padmasari-anggraini.com
#
#                                                 linkedin
# 0      www.linkedin.com/in/pt-safitri-safitri-(perser...
# 1      www.linkedin.com/in/ud-dabukke-pranowo-(perser...
# 2                      www.linkedin.com/in/pd-sihombing/
# 3             www.linkedin.com/in/cv-tampubolon-gunawan/
# 4                         www.linkedin.com/in/pt-melani/
# ...                                                  ...
# 24819          www.linkedin.com/in/pt-anggriawan-melani/
# 24820  www.linkedin.com/in/perum-sihombing-(persero)-...
# 24821  www.linkedin.com/in/cv-nashiruddin-suryatmi-(p...
# 24822    www.linkedin.com/in/cv-mardhiyah-manullang-tbk/
# 24823        www.linkedin.com/in/pt-padmasari-anggraini/
#
# [24824 rows x 6 columns]

# %%
drop_df = df.drop(['job_title', 'job_description'], axis=1)

concatenated_df = pd.concat([new_df, faker_df, drop_df], axis=1)
concatenated_df
# Out:
#                                                 jobTitle  \
# 0                            Procurement Department Head
# 1                                            SALES ADMIN
# 2           City Operation Lead Shopee Express (Cirebon)
# 3                                   Japanese Interpreter
# 4                                      Admin Online Shop
# ...                                                  ...
# 24819                                         Accounting
# 24820                                   Staff Accounting
# 24821                                 Frontend Developer
# 24822                                    Account Manager
# 24823  Credit Marketing Officer (CMO) - Tangerang & C...
#
#                                              description  \
# 0      Job Role  1. Responsible for material availabi...
# 1      Internal Sales   AdminJob Description  We are ...
# 2      Job Description Responsible for HSE implementa...
# 3      Overview  Our clients is manufacture for autom...
# 4      Deskripsi Pekerjaan Dapat menggunakan aplikasi...
# ...                                                  ...
# 24819  Usia maksimal 35 tahunPendidikan S1 Accounting...
# 24820  Candidate must possess at least Bachelor s Deg...
# 24821  job description  1.Participate in the daily de...
# 24822  Tugas   Tanggung Jawab Melakukan program pemas...
# 24823  CMO Motor BaruMelakukan penjualan produk pembi...
#
#                                  companyName                       address  \
# 0           PT Safitri Safitri (Persero) Tbk     Jalan Suryakencana No. 12
# 1           UD Dabukke Pranowo (Persero) Tbk  Jalan Rungkut Industri No. 2
# 2                               PD Sihombing       Gg. Moch. Ramdan No. 94
# 3                      CV Tampubolon Gunawan          Gg. Joyoboyo No. 004
# 4                                  PT Melani               Gang BKR No. 83
# ...                                      ...                           ...
# 24819                   PT Anggriawan Melani         Jl. Ciumbuleuit No. 1
# 24820          Perum Sihombing (Persero) Tbk       Gg. Asia Afrika No. 476
# 24821  CV Nashiruddin Suryatmi (Persero) Tbk       Gang Cihampelas No. 894
# 24822             CV Mardhiyah Manullang Tbk             Jl. Cempaka No. 3
# 24823                 PT Padmasari Anggraini             Jl. Kutai No. 015
#
#                phoneNumber                                        email  \
# 0               0808211883       ptsafitrisafitri(persero)tbk@email.com
# 1        +62 (69) 978-8049       uddabukkepranowo(persero)tbk@email.com
# 2        +62-0175-406-9923                        pdsihombing@email.com
# 3        +62-0126-859-2299                cvtampubolongunawan@email.com
# 4        +62 (22) 958-5994                           ptmelani@email.com
# ...                    ...                                          ...
# 24819  +62 (0753) 440-1069                 ptanggriawanmelani@email.com
# 24820         088 916 5849         perumsihombing(persero)tbk@email.com
# 24821    +62 (15) 140 1171  cvnashiruddinsuryatmi(persero)tbk@email.com
# 24822    +62 (34) 362-5283            cvmardhiyahmanullangtbk@email.com
# 24823  +62 (0293) 341-4033               ptpadmasarianggraini@email.com
#
#                                              website  \
# 0           www.pt-safitri-safitri-(persero)-tbk.com
# 1           www.ud-dabukke-pranowo-(persero)-tbk.com
# 2                               www.pd-sihombing.com
# 3                      www.cv-tampubolon-gunawan.com
# 4                                  www.pt-melani.com
# ...                                              ...
# 24819                   www.pt-anggriawan-melani.com
# 24820          www.perum-sihombing-(persero)-tbk.com
# 24821  www.cv-nashiruddin-suryatmi-(persero)-tbk.com
# 24822             www.cv-mardhiyah-manullang-tbk.com
# 24823                 www.pt-padmasari-anggraini.com
#
#                                                 linkedin     id  \
# 0      www.linkedin.com/in/pt-safitri-safitri-(perser...      1
# 1      www.linkedin.com/in/ud-dabukke-pranowo-(perser...      2
# 2                      www.linkedin.com/in/pd-sihombing/      3
# 3             www.linkedin.com/in/cv-tampubolon-gunawan/      4
# 4                         www.linkedin.com/in/pt-melani/      5
# ...                                                  ...    ...
# 24819          www.linkedin.com/in/pt-anggriawan-melani/  24820
# 24820  www.linkedin.com/in/perum-sihombing-(persero)-...  24821
# 24821  www.linkedin.com/in/cv-nashiruddin-suryatmi-(p...  24822
# 24822    www.linkedin.com/in/cv-mardhiyah-manullang-tbk/  24823
# 24823        www.linkedin.com/in/pt-padmasari-anggraini/  24824
#
#               location                              career_level  \
# 0         Jakarta Raya                   Manajer/Asisten Manajer
# 1        Jakarta Barat                    Supervisor/Koordinator
# 2              Cirebon                    Supervisor/Koordinator
# 3               Bekasi  Pegawai (non-manajemen & non-supervisor)
# 4            Tangerang  Pegawai (non-manajemen & non-supervisor)
# ...                ...                                       ...
# 24819           Banten                    Supervisor/Koordinator
# 24820           Bekasi  Pegawai (non-manajemen & non-supervisor)
# 24821    Jakarta Pusat  Pegawai (non-manajemen & non-supervisor)
# 24822  Jakarta Selatan  Pegawai (non-manajemen & non-supervisor)
# 24823        Tangerang  Pegawai (non-manajemen & non-supervisor)
#
#       experience_level                                    education_level  \
# 0              5 tahun  Sarjana (S1),Diploma Pascasarjana,Gelar Profes...
# 1              4 tahun                                       Sarjana (S1)
# 2              5 tahun  Sarjana (S1),Diploma Pascasarjana,Gelar Profes...
# 3              2 tahun  Sertifikat Professional,D3 (Diploma),D4 (Diplo...
# 4              1 tahun                                    SMA,SMU/SMK/STM
# ...                ...                                                ...
# 24819          2 tahun                                       Sarjana (S1)
# 24820          2 tahun                                       Sarjana (S1)
# 24821          2 tahun                                       Sarjana (S1)
# 24822          2 tahun                                       Sarjana (S1)
# 24823          1 tahun  SMA,SMU/SMK/STM,Sertifikat Professional,D3 (Di...
#
#       employment_type                                      job_function  \
# 0         Penuh Waktu           Manufaktur,Pembelian/Manajemen Material
# 1         Penuh Waktu             Penjualan / Pemasaran,Penjualan Ritel
# 2         Penuh Waktu                 Pelayanan,Logistik/Rantai Pasokan
# 3         Penuh Waktu                           Lainnya,Jurnalis/Editor
# 4         Penuh Waktu                  Penjualan / Pemasaran,E-commerce
# ...               ...                                               ...
# 24819         Kontrak  Akuntansi / Keuangan,Akuntansi Umum / Pembiayaan
# 24820         Kontrak  Akuntansi / Keuangan,Akuntansi Umum / Pembiayaan
# 24821     Penuh Waktu   Komputer/Teknologi Informasi,IT-Perangkat Lunak
# 24822     Penuh Waktu       Penjualan / Pemasaran,Penjualan - Korporasi
# 24823         Kontrak  Akuntansi / Keuangan,Perbankan / Jasa Finansial
#
#                                     company_industry
# 0                            Manajemen/Konsulting HR
# 1                                      Umum & Grosir
# 2                                 Retail/Merchandise
# 3                            Manajemen/Konsulting HR
# 4                                 Retail/Merchandise
# ...                                              ...
# 24819            Makanan & Minuman/Katering/Restoran
# 24820                            Manufaktur/Produksi
# 24821                   Perbankan/Pelayanan Keuangan
# 24822  Komputer/Teknik Informatika (Perangkat Keras)
# 24823                   Perbankan/Pelayanan Keuangan
#
# [24824 rows x 16 columns]

# %%
concatenated_df.to_csv("dataset/data_cleaned_v2.csv", index=False)
